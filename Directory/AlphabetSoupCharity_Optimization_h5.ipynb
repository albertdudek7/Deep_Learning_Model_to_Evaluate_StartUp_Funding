# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies

# !pip install keras-tuner
# %matplotlib inline

import os
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.utils import np_utils
import warnings
warnings.filterwarnings('ignore')
from google.colab import drive
drive.mount('/content/drive')


#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
# Collecting keras-tuner
#   Downloading keras_tuner-1.3.5-py3-none-any.whl (176 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.1/176.1 kB 1.9 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (23.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (2.31.0)
# Collecting kt-legacy (from keras-tuner)
#   Downloading kt_legacy-1.0.5-py3-none-any.whl (9.6 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (2023.7.22)
# Installing collected packages: kt-legacy, keras-tuner
# Successfully installed keras-tuner-1.3.5 kt-legacy-1.0.5
# Mounted at /content/drive
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df = application_df.drop(columns=['EIN'], axis=1)
application_df.head()
# Out:
#                                        NAME APPLICATION_TYPE  \
# 0              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Determine the number of unique values in each column.
application_df.nunique()
# Out:
# NAME                      19568
# APPLICATION_TYPE             17
# AFFILIATION                   6
# CLASSIFICATION               71
# USE_CASE                      5
# ORGANIZATION                  4
# STATUS                        2
# INCOME_AMT                    9
# SPECIAL_CONSIDERATIONS        2
# ASK_AMT                    8747
# IS_SUCCESSFUL                 2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
application_counts = application_df['APPLICATION_TYPE'].value_counts()
application_counts
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace = list(application_counts[application_counts<100].index)

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# T9         156
# Other      120
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
classification_counts = application_df['CLASSIFICATION'].value_counts()
classification_counts
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
classification_counts_gt1 = classification_counts.loc[classification_counts>1]
classification_counts_gt1.head()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace = list(classification_counts[classification_counts<1000].index)

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
application_numeric = pd.get_dummies(application_df)

# %%
# Split our preprocessed data into our features and target arrays

X = application_numeric.drop(['IS_SUCCESSFUL'],axis=1)
y= application_numeric['IS_SUCCESSFUL']

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=58)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.

# adding an extra hidden nodes layer to get acheive higher than 75% accuracy
number_of_input_features = len(X_train_scaled[0])
hidden_nodes_layer1 = 10
hidden_nodes_layer2 = 8
hidden_nodes_layer3 = 6


nn_optimized = tf.keras.models.Sequential()

# First hidden layer
nn_optimized.add(tf.keras.layers.Dense(units=hidden_nodes_layer1,
                            input_dim=number_of_input_features, activation="relu"))

# Second hidden layer
nn_optimized.add(tf.keras.layers.Dense(
    units=hidden_nodes_layer2, activation="sigmoid"))

# Added Third hidden layer to optimized model for better accuracy results

nn_optimized.add(tf.keras.layers.Dense(
    units=hidden_nodes_layer3, activation="sigmoid"))

# Output layer
nn_optimized.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn_optimized.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 10)                196130
#
#  dense_1 (Dense)             (None, 8)                 88
#
#  dense_2 (Dense)             (None, 6)                 54
#
#  dense_3 (Dense)             (None, 1)                 7
#
# =================================================================
# Total params: 196,279
# Trainable params: 196,279
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn_optimized.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# Train the model
fit_model = nn_optimized.fit(X_train_scaled, y_train, epochs=25)
# Out:
# Epoch 1/25
# 804/804 [==============================] - 9s 9ms/step - loss: 0.5768 - accuracy: 0.7491
# Epoch 2/25
# 804/804 [==============================] - 6s 7ms/step - loss: 0.4471 - accuracy: 0.7977
# Epoch 3/25
# 804/804 [==============================] - 7s 8ms/step - loss: 0.3113 - accuracy: 0.8809
# Epoch 4/25
# 804/804 [==============================] - 5s 6ms/step - loss: 0.2277 - accuracy: 0.9189
# Epoch 5/25
# 804/804 [==============================] - 6s 8ms/step - loss: 0.1815 - accuracy: 0.9350
# Epoch 6/25
# 804/804 [==============================] - 5s 6ms/step - loss: 0.1532 - accuracy: 0.9485
# Epoch 7/25
# 804/804 [==============================] - 6s 7ms/step - loss: 0.1409 - accuracy: 0.9496
# Epoch 8/25
# 804/804 [==============================] - 6s 8ms/step - loss: 0.1544 - accuracy: 0.9426
# Epoch 9/25
# 804/804 [==============================] - 5s 7ms/step - loss: 0.1175 - accuracy: 0.9544
# Epoch 10/25
# 804/804 [==============================] - 6s 8ms/step - loss: 0.1083 - accuracy: 0.9599
# Epoch 11/25
# 804/804 [==============================] - 6s 7ms/step - loss: 0.1043 - accuracy: 0.9603
# Epoch 12/25
# 804/804 [==============================] - 7s 8ms/step - loss: 0.1011 - accuracy: 0.9614
# Epoch 13/25
# 804/804 [==============================] - 5s 6ms/step - loss: 0.0991 - accuracy: 0.9616
# Epoch 14/25
# 804/804 [==============================] - 5s 6ms/step - loss: 0.0977 - accuracy: 0.9621
# Epoch 15/25
# 804/804 [==============================] - 5s 6ms/step - loss: 0.0959 - accuracy: 0.9624
# Epoch 16/25
# 804/804 [==============================] - 5s 6ms/step - loss: 0.0944 - accuracy: 0.9625
# Epoch 17/25
# 804/804 [==============================] - 6s 8ms/step - loss: 0.0939 - accuracy: 0.9628
# Epoch 18/25
# 804/804 [==============================] - 6s 7ms/step - loss: 0.0925 - accuracy: 0.9632
# Epoch 19/25
# 804/804 [==============================] - 5s 7ms/step - loss: 0.0930 - accuracy: 0.9627
# Epoch 20/25
# 804/804 [==============================] - 6s 7ms/step - loss: 0.0915 - accuracy: 0.9635
# Epoch 21/25
# 804/804 [==============================] - 6s 7ms/step - loss: 0.0917 - accuracy: 0.9631
# Epoch 22/25
# 804/804 [==============================] - 6s 8ms/step - loss: 0.0912 - accuracy: 0.9632
# Epoch 23/25
# 804/804 [==============================] - 5s 6ms/step - loss: 0.0904 - accuracy: 0.9635
# Epoch 24/25
# 804/804 [==============================] - 7s 9ms/step - loss: 0.0903 - accuracy: 0.9640
# Epoch 25/25
# 804/804 [==============================] - 6s 7ms/step - loss: 0.0901 - accuracy: 0.9633

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn_optimized.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 1s - loss: 0.5259 - accuracy: 0.7706 - 536ms/epoch - 2ms/step
# Loss: 0.5258538722991943, Accuracy: 0.7706122398376465

# %%
# Export our model to HDF5 file
filename = '/content/drive/MyDrive/AlphabetSoupCharity_Optimization.h5'

#Save the model to a HDF5 file
nn_optimized.save(filename)
